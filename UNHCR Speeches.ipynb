# %%
import pandas as pd

df = pd.read_json("UNHCR speeches/speeches.json")
df.sample(5)
# Out:
#        author                                                 by  \
# 446     ogata       Statements by High Commissioner, 23 May 1992
# 531  hartling      Statements by High Commissioner, 16 July 1980
# 271     ogata  Statements by High Commissioner, 16 February 1998
# 661     lindt      Statements by High Commissioner, 9 April 1959
# 595      khan  Statements by High Commissioner, 20 November 1967
#
#                                                content          date  \
# 446    \n\n"Fortress Europe? Refugees and migrants:...  706572000000
# 531    \n\nStatement by Mr. Poul Hartling, United N...  332546400000
# 271    \n\nStatement by Mrs. Sadako Ogata, United N...  887583600000
# 661    \n\nStatement by Dr. Auguste R. Lindt, Unite... -338695200000
# 595    \n\nStatement by Prince Sadruddin Aga Khan, ...  -66790800000
#
#              id                                              title
# 446  3ae68fcd34  "Fortress Europe? Refugees and migrants: their...
# ...
